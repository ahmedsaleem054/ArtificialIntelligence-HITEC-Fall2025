# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age



class Job:
    def __init__(self, designation, salary):
        self.designation = designation
        self.salary = salary

class Employee(Person, Job):
    def __init__(self, name, age, designation, salary):

        Person.__init__(self, name, age)
        
        Job.__init__(self, designation, salary)

    def display_details(self):
        print(f"Employee Details:")
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Designation: {self.designation}")
        print(f"Salary: ${self.salary}")

emp = Employee("Ahmed Saleem", 20, "Software Analyst", 50000)
emp.display_details()

# %%
import math

class Circle:
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return math.pi * (self.radius ** 2)

    def perimeter(self):
        return 2 * math.pi * self.radius

circle = Circle(5)
print(f"Area: {circle.area():.2f}")
print(f"Perimeter: {circle.perimeter():.2f}")

# %%
class Power:
    def pow(self, x, n):
        """
        Compute x^n using iterative exponentiation by squaring.
        Handles positive, negative, and zero exponents.
        """
        if n == 0:
            return 1
 
        negative = False
        if n < 0:
            negative = True
            n = -n
        
        result = 1
        current_product = x
        
        while n > 0:

            if n % 2 == 1:
                result *= current_product
            current_product *= current_product 
            n //= 2  
        
        return 1 / result if negative else result

power = Power()
print(power.pow(2, 8))    
print(power.pow(2, -3))   
print(power.pow(5, 0))

# %%
class Item:
    def setItem(self, name, description, price):
        self.name = name
        self.description = description
        self.price = price

    def viewFullDescription(self):
        print("Item:", self.name)
        print("Description:", self.description)
        print("Price:", self.price)

    def addToShoppingBasket(self):
        print(self.name, "added to cart.")

    def removeFromShoppingBasket(self):
        print(self.name, "removed from cart.")

class MP3(Item):
    def set_mp3(self, artist, duration):
        self.artist = artist
        self.duration = duration

    def play(self):
        print("Music by", self.artist)
        print("Song duration", self.duration)

    def download(self):
        pass

class DVD(Item):
    def set_dvd(self, rating, actors):
        self.rating = rating
        self.actors = actors

    def viewTrailer(self):
        print("Viewing trailer with actors:", self.actors)

class Book(Item):
    def set_book(self, author, numberOfPages, genre):
        self.author = author
        self.numberOfPages = numberOfPages
        self.genre = genre

    def previewContent(self):
        print("Previewing content of book by", self.author)
        print("Book genre:", self.genre)

Item1 = Item()
Item1.setItem("DVD", "HORROR", 1800)
Item1.viewFullDescription()
Item1.addToShoppingBasket()
Item1.removeFromShoppingBasket()

MP3_1 = MP3()
MP3_1.set_mp3("ZAIN", 2)
MP3_1.play()
MP3_1.download()

DVD1 = DVD()
DVD1.set_dvd("PG-13", "MAJID")
DVD1.viewTrailer()

Book1 = Book()
Book1.set_book("FAIZAN", 689, "THRILLER")
Book1.previewContent()
